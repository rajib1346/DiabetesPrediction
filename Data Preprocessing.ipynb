# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Dataset
#                DataFrameName = pd.read_csv('DrivePath')

# %%
df = pd.read_csv('E:/Shuvo/diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72           35.0        0  33.6
# 1              1     85.0             66           29.0        0  26.6
# 2              8    183.0             64            0.0        0  23.3
# 3              1     89.0             66           23.0       94  28.1
# 4              0    137.0             40           35.0      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 768           10    168.0             74            0.0        0  38.0
# 769           10    139.0             80            0.0        0  27.1
# 770            1    189.0             60           23.0      846  30.1
# 771            9     89.0             62            0.0        0  22.5
# 772           10    101.0             76           48.0      180  32.9
#
#      DiabetesPedigreeFunction  Age label
# 0                       0.627   50   yes
# ...

# %% [markdown]
# # Visulalize the Dataset Propertices

# %% [markdown]
# # a. Display Full Dataset:
#                 pd.set_option('display.max_columns', None)
# 				pd.set_option('display.max_Rows', None)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_Rows', None)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72           35.0        0  33.6
# 1              1     85.0             66           29.0        0  26.6
# 2              8    183.0             64            0.0        0  23.3
# 3              1     89.0             66           23.0       94  28.1
# 4              0    137.0             40           35.0      168  43.1
# 5              5    116.0             74            0.0        0  25.6
# 6              3     78.0             50           32.0       88  31.0
# 7             10    115.0              0            0.0        0  35.3
# 8              2    197.0             70           45.0      543  30.5
# 9              8    125.0             96            0.0        0   0.0
# 10             4    110.0             92            0.0        0  37.6
# 11            10    168.0             74            0.0        0  38.0
# ...

# %% [markdown]
# # b. View Total Number of Row and Column
# 			DataFrameName.shape

# %%
df.shape
# Out:
# (773, 9)

# %% [markdown]
# # c. View All Columns Name
#            DataFrameName.columns

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'label'],
#       dtype='object')

# %% [markdown]
# # d. View Datypes
# 		  DataFrameName.dtypes

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                     float64
# BloodPressure                 int64
# SkinThickness               float64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# label                        object
# dtype: object

# %% [markdown]
# # Data Set Preprocessing

# %% [markdown]
# #        a. Check Duplicates Rows
#             -> Extract Duplicate Rows
#                 DataFrameName.loc[DataFrameNamedf.duplicated(), :])

# %%
df.loc[df.duplicated(), :]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 768           10    168.0             74            0.0        0  38.0
# 769           10    139.0             80            0.0        0  27.1
# 770            1    189.0             60           23.0      846  30.1
# 771            9     89.0             62            0.0        0  22.5
# 772           10    101.0             76           48.0      180  32.9
#
#      DiabetesPedigreeFunction  Age label
# 768                     0.537   34   yes
# 769                     1.441   57    no
# 770                     0.398   59   yes
# 771                     0.142   33    no
# 772                     0.171   63    no

# %% [markdown]
# #        b. Remove the Duplicates Rows
#             ->Remove Duplicate Rows
# 				NewDataFrameName=DataFrameName.drop_duplicates(keep='first')

# %%
df_RD=df.drop_duplicates(keep='first')
df_RD.shape
# Out:
# (768, 9)

# %%
df_RD
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72           35.0        0  33.6
# 1              1     85.0             66           29.0        0  26.6
# 2              8    183.0             64            0.0        0  23.3
# 3              1     89.0             66           23.0       94  28.1
# 4              0    137.0             40           35.0      168  43.1
# 5              5    116.0             74            0.0        0  25.6
# 6              3     78.0             50           32.0       88  31.0
# 7             10    115.0              0            0.0        0  35.3
# 8              2    197.0             70           45.0      543  30.5
# 9              8    125.0             96            0.0        0   0.0
# 10             4    110.0             92            0.0        0  37.6
# 11            10    168.0             74            0.0        0  38.0
# ...

# %% [markdown]
# #  		c. Extract Null Columns
#             ->Check Null Columns
# 				DataFrameName.isnull().any()
#             -> Find Out Total Number of Null Cell in Each Column
#                 DataFrameName.isnull().sum()

# %%
df_RD.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                      True
# BloodPressure               False
# SkinThickness                True
# Insulin                     False
# BMI                          True
# DiabetesPedigreeFunction     True
# Age                         False
# label                       False
# dtype: bool

# %%
df_RD.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     1
# BloodPressure               0
# SkinThickness               1
# Insulin                     0
# BMI                         3
# DiabetesPedigreeFunction    1
# Age                         0
# label                       0
# dtype: int64

# %% [markdown]
# #       d. Extract Null Rows That Contains Null Cell
# 				DataFrameName[DataFrameName.isnull().any(axis=1)]

# %%
df_RD[df_RD.isnull().any(axis=1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 22             7    196.0             90            0.0        0   NaN
# 31             3    158.0             76           36.0      245   NaN
# 33             6     92.0             92            NaN        0  19.9
# 38             2     90.0             68           42.0        0   NaN
# 93             4      NaN             72            0.0        0  23.8
# 118            4     97.0             60           23.0        0  28.2
#
#      DiabetesPedigreeFunction  Age label
# 22                      0.451   41   yes
# 31                      0.851   28   yes
# 33                      0.188   28    no
# 38                      0.503   27   yes
# 93                      0.277   60   yes
# 118                       NaN   22    no

# %% [markdown]
# #  	e. Fill The Null Value Using Mean Value
# 				DataFrameName['ColumnName']=DataFrameName['ColumnName'].replace(np.NaN,
#                 DataFrameNamedf['ColumnName'].mean())
# 			    Or. Remove That Rows
#                         DataFrameName.dropna(inplace=True)

# %%
df_RD['Glucose']=df_RD['Glucose'].replace(np.NaN, df['Glucose'].mean())
df_RD['SkinThickness']=df_RD['SkinThickness'].replace(np.NaN, df['SkinThickness'].mean())
df_RD['BMI']=df_RD['BMI'].replace(np.NaN, df['BMI'].mean())
df_RD['DiabetesPedigreeFunction']=df_RD['DiabetesPedigreeFunction'].replace(np.NaN, df['DiabetesPedigreeFunction'].mean())
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_12460\3296509701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RD['Glucose']=df_RD['Glucose'].replace(np.NaN, df['Glucose'].mean())
# C:\Users\acer\AppData\Local\Temp\ipykernel_12460\3296509701.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RD['SkinThickness']=df_RD['SkinThickness'].replace(np.NaN, df['SkinThickness'].mean())
# C:\Users\acer\AppData\Local\Temp\ipykernel_12460\3296509701.py:3: SettingWithCopyWarning:
# ...

# %%
df_RD.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# label                       False
# dtype: bool

# %% [markdown]
# # f. Label Encoding

# %%
df_RD['label'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df_RD['label'].value_counts()
# Out:
# no     500
# yes    268
# Name: label, dtype: int64

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df_RD['label_en']=label_encoder.fit_transform(df_RD['label'])
df_RD
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_12460\1574550550.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RD['label_en']=label_encoder.fit_transform(df_RD['label'])
#      Pregnancies     Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6  148.000000             72      35.000000        0
# 1              1   85.000000             66      29.000000        0
# 2              8  183.000000             64       0.000000        0
# 3              1   89.000000             66      23.000000       94
# 4              0  137.000000             40      35.000000      168
# 5              5  116.000000             74       0.000000        0
# 6              3   78.000000             50      32.000000       88
# ...

# %%
sorted(df_RD['label'].unique().astype(str))
# Out:
# ['no', 'yes']

# %%
df_RD
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6  148.000000             72      35.000000        0
# 1              1   85.000000             66      29.000000        0
# 2              8  183.000000             64       0.000000        0
# 3              1   89.000000             66      23.000000       94
# 4              0  137.000000             40      35.000000      168
# 5              5  116.000000             74       0.000000        0
# 6              3   78.000000             50      32.000000       88
# 7             10  115.000000              0       0.000000        0
# 8              2  197.000000             70      45.000000      543
# 9              8  125.000000             96       0.000000        0
# 10             4  110.000000             92       0.000000        0
# 11            10  168.000000             74       0.000000        0
# 12            10  139.000000             80       0.000000        0
# ...

# %% [markdown]
# # g. Data Scalling

# %%
from sklearn import preprocessing

columns_to_scale = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
scaler = preprocessing.MinMaxScaler()
df_RD[columns_to_scale] = scaler.fit_transform(df_RD[columns_to_scale])
df_RD
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_12460\180065166.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RD[columns_to_scale] = scaler.fit_transform(df_RD[columns_to_scale])
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1       0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2       0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3       0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4       0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# 5       0.294118  0.582915       0.606557       0.000000  0.000000  0.381520
# ...

# %% [markdown]
# # h. Save the Dataset
#             DataFrameName.to_csv('DrivePath')

# %%
df_RD.to_csv('E:/Shuvo/phase1.csv')
